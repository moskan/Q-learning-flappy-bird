# %%
# %run train.py
# Out:
# 开始训练Q-Flappy Bird...
# ...
# Episode  100/10000 | Score:   0 | Total Reward: -995.60 | Epsilon: 0.9512
# Episode  200/10000 | Score:   0 | Total Reward: -995.80 | Epsilon: 0.9048
# Episode  300/10000 | Score:   0 | Total Reward: -995.80 | Epsilon: 0.8607
# Episode  400/10000 | Score:   0 | Total Reward: -995.30 | Epsilon: 0.8187
# Episode  500/10000 | Score:   0 | Total Reward: -995.60 | Epsilon: 0.7788
# 模型已保存至: models\q_flappy_episode_500.pkl
# Episode  600/10000 | Score:   0 | Total Reward: -995.80 | Epsilon: 0.7408
# Episode  700/10000 | Score:   0 | Total Reward: -995.70 | Epsilon: 0.7046
# Episode  800/10000 | Score:   0 | Total Reward: -993.50 | Epsilon: 0.6703
# Episode  900/10000 | Score:   0 | Total Reward: -995.70 | Epsilon: 0.6376
# Episode 1000/10000 | Score:   0 | Total Reward: -995.60 | Epsilon: 0.6065
# 模型已保存至: models\q_flappy_episode_1000.pkl
# Episode 1100/10000 | Score:   0 | Total Reward: -995.50 | Epsilon: 0.5769
# ...

# %%
# %run test.py
# Out:
# 加载模型: models/q_flappy_final.pkl
# 模型已加載自: models/q_flappy_final.pkl
#
# ...
# Q-FLAPPY BIRD 演示
# ...
# 游戏控制：
#   SPACE - 开始游戏/重新开始
#   ESC   - 退出游戏
#   R     - 重置游戏
# ...
#
# 游戏状态：对局 1/5
#   游戏开始！
#   游戏结束！分数: 8 | 总奖励: -829.10
#
# 游戏状态：对局 2/5
#   游戏开始！
#   游戏结束！分数: 2 | 总奖励: -943.40
#
# 游戏状态：对局 3/5
#   游戏开始！
#   游戏结束！分数: 3 | 总奖励: -924.70
#
# 游戏状态：对局 4/5
#   游戏开始！
#   游戏结束！分数: 1 | 总奖励: -962.20
#
# 游戏状态：对局 5/5
#   游戏开始！
#   游戏结束！分数: 1 | 总奖励: -962.70
# ...
# 演示结束！
# ...
